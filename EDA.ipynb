# %% [markdown]
# # Exploratory data analysis

# %%
import os
from config import get_cfg_defaults
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
INPUT = "/media/tungthanhlee/SSD/grand_challenge/dataset/LNDB_segmentation/submission/predictedNodulesB"
ex = np.load("/media/tungthanhlee/SSD/grand_challenge/dataset/LNDB_segmentation/submission/predictedNodulesB/LNDb-0001_finding1.npy")
print(ex[0])
# Out:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]

# %%
train_csv = "/media/tungthanhlee/SSD/grand_challenge/dataset/LNDB_segmentation/trainset_csv/trainNodules_gt.csv"
train_csv = pd.read_csv(train_csv)
train_csv
# Out:
#       LNDbID  RadID RadFindingID  FindingID           x           y  \
# 0          1  1,2,3        1,1,1          1  -44.203451 -119.073242
# 1          1      1            2          2   25.852539 -126.969727
# 2          2  1,2,3        1,1,3          1   88.895508 -123.867513
# 3          2    1,3          2,2          2   63.534180 -112.756836
# 4          2    1,3          3,5          3 -103.850586 -116.742188
# ...      ...    ...          ...        ...         ...         ...
# 1214     312      1            2          2   56.350117  -72.253663
# 1215     312      2            2          3   97.832825  -63.763479
# 1216     312      2            3          4  -50.744508  -49.309899
# 1217     312      2            4          5   99.839636  -63.420362
# 1218     312      2            5          6  -91.313708  -79.837964
#
#                 z  AgrLevel  Nodule      Volume  Text
# 0      -37.500000         3       1  222.360697   5.0
# ...

# %%
train_csv[train_csv["Nodule"] == 1 ]
# Out:
#       LNDbID  RadID RadFindingID  FindingID           x           y      z  \
# 0          1  1,2,3        1,1,1          1  -44.203451 -119.073242  -37.5
# 1          1      1            2          2   25.852539 -126.969727  -45.5
# 2          2  1,2,3        1,1,3          1   88.895508 -123.867513 -129.5
# 3          2    1,3          2,2          2   63.534180 -112.756836 -117.5
# 4          2    1,3          3,5          3 -103.850586 -116.742188 -253.0
# ...      ...    ...          ...        ...         ...         ...    ...
# 1206     310      2            1          2 -100.263672 -224.498047 -142.5
# 1207     310      2            2          3 -121.220703 -181.138672 -193.5
# 1208     310      2            3          4  141.826172 -151.509766 -143.5
# 1209     310      2            4          5  125.205078 -127.662109  -57.5
# 1212     311      2            1          1   56.570312  -98.507812 -329.4
#
#       AgrLevel  Nodule      Volume  Text
# ...

# %%
import os
sample = "/media/tungthanhlee/SSD/grand_challenge/dataset/LNDB_segmentation/submission/predictedNodulesB"
os.listdir(sample).sort()
# Out:
# 625
# LNDb-0086_finding3.npy
# LNDb-0001_finding1.npy
# LNDb-0001_finding2.npy
# LNDb-0002_finding1.npy
# LNDb-0002_finding2.npy
# LNDb-0002_finding3.npy
# LNDb-0002_finding4.npy
# LNDb-0002_finding5.npy
# LNDb-0002_finding7.npy
# LNDb-0002_finding8.npy
# LNDb-0003_finding1.npy
# LNDb-0003_finding2.npy
# LNDb-0003_finding3.npy
# LNDb-0003_finding5.npy
# LNDb-0004_finding1.npy
# LNDb-0004_finding2.npy
# LNDb-0005_finding2.npy
# LNDb-0007_finding1.npy
# LNDb-0008_finding1.npy
# LNDb-0008_finding2.npy
# LNDb-0008_finding3.npy
# LNDb-0010_finding1.npy
# LNDb-0010_finding10.npy
# LNDb-0010_finding11.npy
# LNDb-0010_finding12.npy
# LNDb-0010_finding2.npy
# LNDb-0010_finding3.npy
# LNDb-0010_finding4.npy
# LNDb-0010_finding5.npy
# LNDb-0010_finding6.npy
# LNDb-0010_finding7.npy
# LNDb-0010_finding9.npy
# LNDb-0011_finding1.npy
# LNDb-0011_finding2.npy
# LNDb-0011_finding3.npy
# LNDb-0011_finding4.npy
# LNDb-0011_finding5.npy
# LNDb-0011_finding6.npy
# LNDb-0011_finding7.npy
# ...

# %%
scan = "/media/tungthanhlee/SSD/grand_challenge/dataset/LNDB_segmentation/split/scan_cubes2"
print(len(os.listdir(scan)))
for i in os.listdir(scan):
    print(i)
# Out:
# 860
# LNDb-0001_finding1_rad1.npy
# LNDb-0001_finding1_rad2.npy
# LNDb-0001_finding1_rad3.npy
# LNDb-0001_finding2_rad1.npy
# LNDb-0002_finding1_rad1.npy
# LNDb-0002_finding1_rad2.npy
# LNDb-0002_finding1_rad3.npy
# LNDb-0002_finding2_rad1.npy
# LNDb-0002_finding2_rad3.npy
# LNDb-0002_finding3_rad1.npy
# LNDb-0002_finding3_rad3.npy
# LNDb-0002_finding4_rad1.npy
# LNDb-0002_finding4_rad3.npy
# LNDb-0002_finding5_rad1.npy
# LNDb-0003_finding1_rad1.npy
# LNDb-0003_finding1_rad3.npy
# LNDb-0003_finding2_rad1.npy
# LNDb-0003_finding2_rad3.npy
# LNDb-0003_finding3_rad1.npy
# LNDb-0003_finding3_rad3.npy
# LNDb-0003_finding4_rad3.npy
# LNDb-0004_finding1_rad1.npy
# LNDb-0004_finding1_rad2.npy
# LNDb-0004_finding1_rad3.npy
# LNDb-0004_finding2_rad1.npy
# LNDb-0004_finding2_rad3.npy
# LNDb-0004_finding3_rad1.npy
# LNDb-0005_finding1_rad3.npy
# LNDb-0008_finding1_rad1.npy
# LNDb-0008_finding1_rad3.npy
# LNDb-0008_finding2_rad1.npy
# LNDb-0008_finding2_rad2.npy
# LNDb-0008_finding2_rad3.npy
# ...

# %%
a = np.load("/media/tungthanhlee/SSD/grand_challenge/dataset/LNDB_segmentation/submission/predictedNodulesB/LNDb-0001_finding1.npy")
type(a[1][1][1])
# Out:
# numpy.bool_
